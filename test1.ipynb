# %%
file_path = '/Volumes/G-DRIVE mobile/낙농_로봇착유기_데이터(agrirobotech).csv'

# %%
import pandas as pd

# 인코딩 오류 방지를 위해 encoding 옵션 추가
df = pd.read_csv(file_path,encoding='cp949')

# 데이터 잘 불러와졌는지 확인
df
# Out:
#        농장아이디            개체번호  축산업등록번호 축종코드       제조사 아이디  장비코드  장비번호  \
# 0      20278  20130816010079      NaN  D00  agrirobotech   NaN   NaN
# 1      20278  20130816010079      NaN  D00  agrirobotech   NaN   NaN
# 2      20278  20130816010079      NaN  D00  agrirobotech   NaN   NaN
# 3      20278  20130816010079      NaN  D00  agrirobotech   NaN   NaN
# 4      20278  20130816010079      NaN  D00  agrirobotech   NaN   NaN
# ...      ...             ...      ...  ...           ...   ...   ...
# 27921  20264  20191027020116      NaN  D00  agrirobotech   NaN   NaN
# 27922  20264  20191027020116      NaN  D00  agrirobotech   NaN   NaN
# 27923  20264  20191027020116      NaN  D00  agrirobotech   NaN   NaN
# 27924  20264  20191027020116      NaN  D00  agrirobotech   NaN   NaN
# 27925  20264  20191027020116      NaN  D00  agrirobotech   NaN   NaN
#
#                         측정일시  착유량                 착유시작일시  ...  색상    온도  유지방  \
# ...
